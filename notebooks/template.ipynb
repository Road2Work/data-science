# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Input Nama]
# - **Email:** [Input Email]
# - **ID Dicoding:** [Input Username]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** xxx
# - **Pertanyaan 2:** xxx
# - ...

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df ...

# %%
# 1. Baca sumber datanya
df = pd.read_csv('../answer_quality_dataset_dirty.csv')

print(f"Total Data: {df.shape[0]} Baris")
df.head()
# Out:
# Total Data: 5239 Baris
#     sample_id                    domain      role_family  \
# 0  AQD-03716F  Information & Technology        Data & AI
# 1  AQD-FA7056  Information & Technology        Data & AI
# 2  AQD-433BB3  Information & Technology        Data & AI
# 3  AQD-B7FDA1  Information & Technology        Data & AI
# 4  AQD-95CDCC  Information & Technology  Software Tester
#
#               target_role                           competency  \
# 0             ML Engineer            Automated MLOps Pipelines
# 1             ML Engineer              Career Motivation & Fit
# 2             AI Engineer              Career Motivation & Fit
# 3             AI Engineer    Deep Learning Architecture Design
# 4  QA Automation Engineer  Programmatic Integration Validation
#
#                                             question  \
# 0  Pernahkah kamu terlibat dalam merancang pipeli...
# 1  Kalau kamu diterima di posisi ML Engineer ini,...
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying ... problem

# %%
# 1. Mengecek informasi dasar dan tipe data
print("--- Informasi Data ---")
df.info()
# Out:
# --- Informasi Data ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5239 entries, 0 to 5238
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sample_id              5239 non-null   object
#  1   domain                 5239 non-null   object
#  2   role_family            5239 non-null   object
#  3   target_role            5239 non-null   object
#  4   competency             5239 non-null   object
#  5   question               5239 non-null   object
#  6   answer                 5228 non-null   object
#  7   role_relevance         5237 non-null   float64
#  8   star_structure         5226 non-null   float64
#  9   evidence_specificity   5237 non-null   float64
#  10  technical_accuracy     5237 non-null   float64
#  11  communication_clarity  5236 non-null   float64
#  12  self_awareness         5237 non-null   float64
#  13  evidence_level         5239 non-null   int64
# ...

# %%
# 2. Mengecek missing values 
print("\n--- Jumlah Missing Values ---")
missing_values = df.isna().sum()
print(missing_values)
# Out:
# --- Jumlah Missing Values ---
# sample_id                   0
# domain                      0
# role_family                 0
# target_role                 0
# competency                  0
# question                    0
# answer                     11
# role_relevance              2
# star_structure             13
# evidence_specificity        2
# technical_accuracy          2
# communication_clarity       3
# self_awareness              2
# evidence_level              0
# weakness_tags            1747
# need_clarification          0
# clarification_type          0
# final_score_0_100           0
# final_score_0_1             0
# quality_label               6
# has_tool                    0
# has_metric                  0
# has_impact                  0
# has_action                  0
# has_context                 0
# answer_length_words         0
# dtype: int64

# %%
# 3. Mengecek duplikasi
print("\n--- Jumlah Duplikasi ---")
print(df.duplicated().sum())
# Out:
# --- Jumlah Duplikasi ---
# 47

# %%
# 4. Statistik deskriptif
print("\n--- Statistik Deskriptif ---")
display(df.describe())
# Out:
# --- Statistik Deskriptif ---
#        role_relevance  star_structure  evidence_specificity  \
# count     5237.000000     5226.000000           5237.000000
# mean        67.070078       57.537887             56.702501
# std         24.327845       31.408282             30.282117
# min         20.000000        0.000000              0.000000
# 25%         40.000000       20.000000             20.000000
# 50%         70.000000       60.000000             55.000000
# 75%         95.000000       90.000000             90.000000
# max        100.000000      100.000000            100.000000
#
#        technical_accuracy  communication_clarity  self_awareness  \
# count         5237.000000            5236.000000     5237.000000
# mean            62.846095              66.448434       57.160397
# std             27.357555              26.106991       26.398845
# min              0.000000              10.000000        0.000000
# 25%             30.000000              40.000000       30.000000
# ...

# %%
# cek nilai unik untuk kolom kategorikal
print("\n--- Nilai Unik untuk Kolom Kategorikal ---")  
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    unique_values = df[col].unique()
    print(f"{col}: {len(unique_values)} nilai unik")
    print(f"Contoh nilai unik: {unique_values[:5]}\n")
# Out:
# --- Nilai Unik untuk Kolom Kategorikal ---
# sample_id: 5189 nilai unik
# Contoh nilai unik: ['AQD-03716F' 'AQD-FA7056' 'AQD-433BB3' 'AQD-B7FDA1' 'AQD-95CDCC']
#
# domain: 1 nilai unik
# Contoh nilai unik: ['Information & Technology']
#
# role_family: 5 nilai unik
# Contoh nilai unik: ['Data & AI' 'Software Tester' 'Web Development' 'Mobile Development'
#  'Infrastructure, Cloud & Security']
#
# target_role: 16 nilai unik
# Contoh nilai unik: ['ML Engineer' 'AI Engineer' 'QA Automation Engineer' 'Data Analyst'
#  'Frontend Developer']
#
# competency: 58 nilai unik
# Contoh nilai unik: ['Automated MLOps Pipelines' 'Career Motivation & Fit'
#  'Deep Learning Architecture Design' 'Programmatic Integration Validation'
#  'Advanced Component Lifecycles & State']
#
# question: 200 nilai unik
# ...

# %% [markdown]
# **Steps to Take:**
# - xxx
# - xxx

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing Duplicate Data, Missing Value, Format Standarization, Outlier problem

# %%
print("=== Proses Data Cleaning ===")
df_clean = df.copy()

# 1. Menangani Data Duplikat
df_clean = df_clean.drop_duplicates()
print(f"[-] Data duplikat berhasil dihapus. Sisa baris: {df_clean.shape[0]}")

# 2. Menangani Missing Values (System Error)
# Hapus baris yang kolom-kolom pentingnya bolong/kosong
kolom_kritikal = ['answer', 'quality_label', 'star_structure', 'role_relevance', 'communication_clarity', 'technical_accuracy', 'evidence_specificity', 'self_awareness']
df_clean = df_clean.dropna(subset=kolom_kritikal)
print(f"[-] Missing values karena system error berhasil didrop. Sisa baris: {df_clean.shape[0]}")

# 3. Menangani Missing Values (Business Logic)
# Kolom weakness_tags yang kosong kita isi dengan label 'None' (artinya tidak ada kelemahan)
df_clean['weakness_tags'] = df_clean['weakness_tags'].fillna('None')
print("[-] Missing values pada 'weakness_tags' berhasil diisi dengan 'None'.")

# 4. Standardisasi Teks (Mengatasi Inconsistent Format pada Label)
df_clean['quality_label'] = df_clean['quality_label'].astype(str).str.strip().str.title()
print("[-] Format penulisan quality_label diseragamkan (Weak, Average, Strong).")

# 5. Mengatasi Outlier / Anomali Angka
# Cek dulu ada berapa baris yang kena anomali -99
total_anomali = (df_clean['answer_length_words'] == -99).sum()
print(f"\n[!] Menemukan {total_anomali} baris dengan panjang kata -99.")

# Jalankan fungsi hitung ulang kata hanya untuk baris yang nilainya -99
# .split() akan memecah teks berdasarkan spasi, lalu len() menghitung total katanya
df_clean.loc[df_clean['answer_length_words'] == -99, 'answer_length_words'] = \
    df_clean[df_clean['answer_length_words'] == -99]['answer'].apply(lambda x: len(str(x).split()))

print("[-] Nilai anomali -99 berhasil diperbaiki dengan metode kalkulasi ulang!")
print(f" Sisa baris final (aman tidak ada yang terbuang): {df_clean.shape[0]}")

print("\n=== Proses Cleaning Selesai! Data siap digunakan ===")
# Out:
# === Proses Data Cleaning ===
# [-] Data duplikat berhasil dihapus. Sisa baris: 5192
# [-] Missing values karena system error berhasil didrop. Sisa baris: 5162
# [-] Missing values pada 'weakness_tags' berhasil diisi dengan 'None'.
# [-] Format penulisan quality_label diseragamkan (Weak, Average, Strong).
#
# [!] Menemukan 6 baris dengan panjang kata -99.
# [-] Nilai anomali -99 berhasil diperbaiki dengan metode kalkulasi ulang!
#  Sisa baris final (aman tidak ada yang terbuang): 5162
#
# === Proses Cleaning Selesai! Data siap digunakan ===

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# 5. Visualisasi distribusi target variable
plt.figure(figsize=(6, 4))
sns.countplot(x='quality_label', data=df)
plt.title('Distribusi Kualitas Jawaban')
plt.xlabel('Kualitas Jawaban')
plt.ylabel('Jumlah')
plt.show()
# 6. Visualisasi distribusi fitur numerik
numerical_cols = df.select_dtypes(include=[np.number]).columns
for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribusi {col}')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()
# 7. Visualisasi hubungan antara fitur numerik dan target variable
for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x='quality_label', y=col, data=df)
    plt.title(f'{col} vs Kualitas Jawaban')
    plt.xlabel('Kualitas Jawaban')
    plt.ylabel(col)
    plt.show()
# 8. Visualisasi hubungan antara fitur kategorikal dan target variable
for col in categorical_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=col, hue='quality_label', data=df)
    plt.title(f'{col} vs Kualitas Jawaban')
    plt.xlabel(col)
    plt.ylabel('Jumlah')
    plt.legend(title='Kualitas Jawaban')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** xxx
# - **Conclusion pertanyaan 2:** xxx
# - ...

# %% [markdown]
# **Rekomendasi Action Item:**
# - xxx
# - xxx
